# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_hole = np.loadtxt("../csv-outputs/black-hole-output-theta=85-a=0.99.csv", delimiter=",")
plt.figure(figsize=(15, 15))
max_min_y = len(data_hole)/2
max_min_x = len(data_hole[0])/2
ax = plt.imshow(data_hole, cmap="hot", extent=(-max_min_x,max_min_x,-max_min_y,max_min_y)) #or use cmp gist_heat
plt.xlabel('x_sc / M')
plt.ylabel('y_sc / M')
# plt.savefig("../plots/black_hole_a=.99theta=85_128_72.png", facecolor='w', bbox_inches='tight')
# plt.savefig("../plots/black_hole_a=.18theta=79_128_72.png", facecolor='w', bbox_inches='tight')
plt.savefig("../plots/ray-traced-black-hole-64-36.png", facecolor='w', bbox_inches='tight')
plt.show()
